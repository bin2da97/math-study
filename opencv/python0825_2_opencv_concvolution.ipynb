# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\tj\anaconda3\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\tj\anaconda3\lib\site-packages (from opencv-python) (1.23.5)

# %%
import cv2

# %%
import numpy as np

# %%
x = np.zeros((20,20,3))

# %%
x[:][:][:]=200

# %%
x
# Out:
# array([[[200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.],
#         ...,
#         [200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.]],
#
#        [[200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.],
#         ...,
#         [200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.]],
#
#        [[200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.],
#         ...,
#         [200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.]],
#
#        ...,
#
#        [[200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.],
#         ...,
#         [200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.]],
#
#        [[200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.],
#         ...,
#         [200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.]],
#
#        [[200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.],
#         ...,
#         [200., 200., 200.],
#         [200., 200., 200.],
#         [200., 200., 200.]]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def img_show(title='image',img=None,figsize=(8,5)):
    plt.figure(figsize=figsize)
    
    if type(img)==list:
        if type(title)==list:
            titles=title
        else:
            titles=[]
            for i in range(len(img)):
                titles.append(title)
        for i in range(len(img)):
            if len(img[i].shape)<=2:
                rgbimg=cv2.cvtColor(img[i],cv2.COLOR_GRAY2RGB)
            else:
                rgbimg=cv2.cvtColor(img[i],cv2.COLOR_BGR2RGB)
            plt.subplot(1,len(img),i+1)
            plt.imshow(rgbimg)
            plt.title(titles[i])
            plt.xticks([])
            plt.yticks([])        
        plt.show()
    else:
        if len(img.shape)<3:
            rgbimg=cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
        else:
            rgbimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        plt.imshow(rgbimg)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
        plt.show()

# %% [markdown]
# 3개(Red,Green,Blue)의 채널이 있는 500x500 픽셀 이미지로 검정색 배경의 캔버스를 그린다.

# %%
black_canvas = np.zeros((500,500,3), dtype='uint8')

# %% [markdown]
# zeros()에 255를 더하면 배경색을 흰색으로 변경가능

# %%
white_canvas = np.zeros((500,500,3), dtype='uint8') + 255

# %%
img_show(["Black","White"],[black_canvas,white_canvas])

# %% [markdown]
# <img src="line.JPG">

# %%
green=(0,255,0)
for i in range(10):
    cv2.line(black_canvas,(10,100),(np.random.randint(100),100),green)
    img_show("Green Line",black_canvas)
    cv2.waitKey(1000)

# %% [markdown]
# <img src="1/3.gif"/>

# %% [markdown]
# <img src="1/4.gif"/>

# %% [markdown]
# <img src="1/5.gif"/>

# %% [markdown]
# <img src="1/6.gif"/>

# %% [markdown]
# ## convolution
# 이미지와 커널(필터)와 연산
# 이동하면서 한다

# %% [markdown]
# <img src="1/Comparison_convolution_correlation.svg.png"/>

# %% [markdown]
# <img src="1/Convolution.png"/>

# %% [markdown]
# <img src="캡처1.png">

# %% [markdown]
# <a href="http://www.songho.ca/dsp/convolution/convolution2d_example.html">2차원 공간의 convolution</a>
