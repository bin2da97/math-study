# %%
import numpy as np

# %% [markdown]
# $$ y = 2x+3 $$

# %%
x = [i for i in np.arange(-3,3,0.01)] #시작값,종료값, 증분
x_=np.array(x)

#np.shape(x_)
y=2*x_+3
# y

# %%
np.cos(np.pi/2) < 0.000001
# Out:
# True

# %% [markdown]
# $$ cos^{-1}\theta(\frac{1}{\sqrt{2}} \rightarrow cos(45) = \frac{1}{\sqrt{2}} $$

# %% [markdown]
# $$ cos^{-1}\theta(\frac{\sqrt3}{2} \rightarrow cos(30) = \frac{\sqrt3}{2} $$

# %% [markdown]
# $$ sin^{-1}(\frac{1}{2}) \rightarrow sin(30) = \frac{1}{2} $$

# %%
np.arccos(1/np.sqrt(2))
# Out:
# 0.7853981633974484

# %% [markdown]
# $$ sin^{-1}\theta(\frac{\sqrt3}{2} \rightarrow sin(30) = \frac{\sqrt3}{2} $$

# %%
np.arccos(np.sqrt(3)/2)
# Out:
# 0.5235987755982989

# %%
np.pi/6 #45도 2pi가 360도 pi가 3.1415925
# Out:
# 0.5235987755982988

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x_,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.plot(x_,y)
#
# NameError: name 'x_' is not defined

# %% [markdown]
# $$ \kappa , \int $$

# %% [markdown]
# $$ \begin{bmatrix}
#  3& 2&  \\
#  11&  8&  \\
#  32&  2&  \\
#  1&  3&
# \end{bmatrix} $$

# %% [markdown]
# $$ 2& 7&
# \end{bmatrix} $$

# %% [markdown]
# $$ \lim_{h\rightarrow0} \frac{f(x+h)-f(x)}{h} $$

# %%
def derivative(f,x):
    h=0.000001
    return f(x+h)-f(x)

# %% [markdown]
# 미분의 공식
# $$ (x^n)^{'} = nx^{n-1}  $$
# $$ (x^3)^{'} = 3x^{2}  $$
# $$ 상수는 미분하면 0이다. 왜냐면 미분은 기울기 이므로 상수는 기울어져 있지 않으므로 0이다.$$
# $$ f(2x + 3x^{2})^{'} = 2f^{'}(x) + 3f^{'}(x^{2}) $$
# $$ (x^2)^{'} = 2x $$

# %%
y= 3*x_*x_+5 #ex^2+5
plt.plot(x_*x)

# %%
deri_value = derivative(lambda x:3*x*x+5, x_)
plt.plot(deri_value)

# %%
(deri_value[0]-deri_value[10])/(x_[0]-x_[10])
# Out:
# 5.999999999062439e-06
